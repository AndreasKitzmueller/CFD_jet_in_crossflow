# %% [markdown]
# # Jet in cross-flow - Supplementary
#
# Andreas Kitzmüller, Simon Mader

# %% [markdown]
# ## 1. Pre-considerations and preparations - counterexample
#
# What happens if we do not even think about laminar flow, convergence, and the computational domain?
#
# <video width="850" controls>
#     <source src="supplementary_bad_case/bad_case_mesh20_U1_4_U2_8.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## 2. Simulations and post-processing - videos with meshes
#
# ### Case 1: $u_{pipe} = u_{duct} = 0.1 m/s$
#
# Simulate for 3 seconds to get a steady result (based on cA and cB).

# %% [markdown]
# #### Courant-Friedrichs-Lewy (CFL) number
#
# <div style="display: flex; gap: 20px;">
#   <video width="850" controls>
#     <source src="U1_0_1_U2_0_1/videos/Co_meshes.mp4" type="video/mp4">
#   </video>
# </div>

# %% [markdown]
# ### concentrations of streams A (cA) and B (cB)
#
# <div style="display: flex; gap: 20px;">
#   <video width="850" controls>
#     <source src="U1_0_1_U2_0_1/videos/cA_meshes.mp4" type="video/mp4">
#   </video>
#
#   <video width="850" controls>
#     <source src="U1_0_1_U2_0_1/videos/cB_meshes.mp4" type="video/mp4">
#   </video>
# </div>

# %% [markdown]
# ### velocity and pressure fields
#
# <div style="display: flex; gap: 20px;">
#   <video width="850" controls>
#     <source src="U1_0_1_U2_0_1/videos/U_meshes.mp4" type="video/mp4">
#   </video>
#
#   <video width="850" controls>
#     <source src="U1_0_1_U2_0_1/videos/p_meshes.mp4" type="video/mp4">
#   </video>
# </div>

# %% [markdown]
# ### Case 2: $u_{pipe} = 0.1 m/s,  = u_{duct} = 0.6 m/s$
#
# Simulate for 1.25 seconds to get a steady result (based on cA and cB).

# %% [markdown]
# #### Courant-Friedrichs-Lewy (CFL) number
#
# <div style="display: flex; gap: 20px;">
#   <video width="850" controls>
#     <source src="U1_0_1_U2_0_6/videos/Co_meshes.mp4" type="video/mp4">
#   </video>
# </div>

# %% [markdown]
# ### concentrations of streams A (cA) and B (cB)
#
# <div style="display: flex; gap: 20px;">
#   <video width="850" controls>
#     <source src="U1_0_1_U2_0_6/videos/cA_meshes.mp4" type="video/mp4">
#   </video>
#
#   <video width="850" controls>
#     <source src="U1_0_1_U2_0_6/videos/cB_meshes.mp4" type="video/mp4">
#   </video>
# </div>

# %% [markdown]
# ### velocity and pressure fields
#
# <div style="display: flex; gap: 20px;">
#   <video width="850" controls>
#     <source src="U1_0_1_U2_0_6/videos/U_meshes.mp4" type="video/mp4">
#   </video>
#
#   <video width="850" controls>
#     <source src="U1_0_1_U2_0_6/videos/p_meshes.mp4" type="video/mp4">
#   </video>
# </div>

# %% [markdown]
# ### Case 3: $u_{pipe} = 0.6 m/s,  = u_{duct} = 0.1 m/s$
#
# Simulate for 0.75 seconds to get a steady result (based on cA and cB).

# %% [markdown]
# #### Courant-Friedrichs-Lewy (CFL) number
#
# <div style="display: flex; gap: 20px;">
#   <video width="850" controls>
#     <source src="U1_0_6_U2_0_1/videos/Co_meshes.mp4" type="video/mp4">
#   </video>
# </div>

# %% [markdown]
# ### concentrations of streams A (cA) and B (cB)
#
# <div style="display: flex; gap: 20px;">
#   <video width="850" controls>
#     <source src="U1_0_6_U2_0_1/videos/cA_meshes.mp4" type="video/mp4">
#   </video>
#
#   <video width="850" controls>
#     <source src="U1_0_6_U2_0_1/videos/cB_meshes.mp4" type="video/mp4">
#   </video>
# </div>

# %% [markdown]
# ### velocity and pressure fields
#
# <div style="display: flex; gap: 20px;">
#   <video width="850" controls>
#     <source src="U1_0_6_U2_0_1/videos/U_meshes.mp4" type="video/mp4">
#   </video>
#
#   <video width="850" controls>
#     <source src="U1_0_6_U2_0_1/videos/p_meshes.mp4" type="video/mp4">
#   </video>
# </div>
